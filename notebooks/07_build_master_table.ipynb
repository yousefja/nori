# %% [markdown]
# # 07 Build Master Table

# %% [markdown]
# # **Project:** NORI
# **Author:** Yuseof J
# **Date:** 10/12/25
#
# ### **Purpose**
# Join socioeconomic features (extracted from tract-level government sources) on tract ID
#
# ### **Inputs**
# - `data/raw/tiger_tracts_ny/tl_2025_36_tract.shp`
#
# ### **Outputs**
# - `data/processed/nyc_tracts.gpkg`
#
# --------------------------------------------------------------------------

# %% [markdown]
# ### 0. Imports and Setup

# %%
# package imports
import os
import pandas as pd
import geopandas as gpd
from pathlib import Path

# specify filepaths
path_nyc_tracts = 'data/processed/nyc_tracts.gpkg'
path_cdc_nyc = 'data/processed/cdc_places_nyc.parquet'
#path_opp_atlas = ???
#path_acs_nyc = ???
path_output_master_table = 'data/processed/master_tract_table.parquet'

# ensure cwd is project root for file paths to function properly
project_root = Path(os.getcwd())            # get current directory
while not (project_root / "data").exists(): # keep moving up until in parent
    project_root = project_root.parent
os.chdir(project_root)                      # switch to parent directory

# %% [markdown]
# ### 1. Load Data

# %%
# nyc tracts
gdf_nyc_tracts = gpd.read_file(path_nyc_tracts)

# cdc places nyc
df_cdc_nyc = pd.read_parquet(path_cdc_nyc)

# %%
df_cdc_nyc.head()
# Out:
#       StateAbbr StateDesc CountyName  CountyFIPS    TractFIPS  \
# 49311        NY  New York      Bronx       36005  36005000100
# 49312        NY  New York      Bronx       36005  36005000200
# 49313        NY  New York      Bronx       36005  36005000400
# 49314        NY  New York      Bronx       36005  36005001600
# 49315        NY  New York      Bronx       36005  36005001901
#
#        TotalPopulation TotalPop18plus  ACCESS2_CrudePrev ACCESS2_Crude95CI  \
# 49311             3772          3,760               23.8      (19.1, 29.0)
# 49312             4779          3,714               12.2      ( 9.3, 15.6)
# 49313             6272          4,935               11.3      ( 8.4, 14.6)
# 49314             5795          4,544               15.6      (12.2, 19.1)
# 49315             2292          1,725               14.3      (11.1, 17.9)
#
#        ARTHRITIS_CrudePrev  ... FOODINSECU_Crude95CI  HOUSINSECU_CrudePrev  \
# 49311                 12.9  ...         (51.0, 63.8)                  47.3
# 49312                 18.1  ...         (20.1, 29.2)                  22.7
# 49313                 17.4  ...         (17.4, 25.9)                  20.6
# 49314                 23.4  ...         (31.2, 41.1)                  29.8
# 49315                 15.1  ...         (31.3, 43.0)                  33.3
#
#       HOUSINSECU_Crude95CI  SHUTUTILITY_CrudePrev SHUTUTILITY_Crude95CI  \
# 49311         (42.2, 52.3)                   29.6          (26.0, 33.3)
# 49312         (19.2, 26.4)                   10.4          ( 8.8, 12.1)
# 49313         (17.2, 24.4)                    8.9          ( 7.5, 10.5)
# 49314         (26.0, 33.6)                   15.2          (13.1, 17.3)
# 49315         (28.7, 38.5)                   18.9          (16.0, 22.1)
#
#        LACKTRPT_CrudePrev LACKTRPT_Crude95CI  EMOTIONSPT_CrudePrev  \
# 49311                28.6       (24.5, 32.7)                  46.9
# 49312                10.7       ( 9.0, 12.6)                  32.2
# 49313                 9.4       ( 7.8, 11.2)                  32.4
# 49314                15.4       (13.2, 17.6)                  35.1
# 49315                17.2       (14.6, 20.1)                  35.2
#
#       EMOTIONSPT_Crude95CI                     Geolocation
# 49311         (42.5, 51.5)  POINT (-73.8812065 40.7929362)
# 49312         (28.5, 36.3)  POINT (-73.8566781 40.8081797)
# 49313         (28.4, 36.4)  POINT (-73.8514252 40.8087867)
# 49314         (31.2, 39.0)  POINT (-73.8580764 40.8188478)
# 49315         (31.3, 39.5)  POINT (-73.9280462 40.8067879)
#
# [5 rows x 88 columns]

# %% [markdown]
# ### 2. Merge Data

# %%
# get nyc tract IDs
df_master = gdf_nyc_tracts[['GEOID']].copy()

# ensure GEOID is the same dtype before joins
df_master.GEOID = df_master.GEOID.astype(int)
df_cdc_nyc.TractFIPS = df_cdc_nyc.TractFIPS.astype(int)

# merge tract IDs with cdc places data
df_master = df_master.merge(df_cdc_nyc,
                            how='left',
                            left_on='GEOID',
                            right_on='TractFIPS')        

add some assertion logic - should any of this be added in previous notebooks?

assert(df_cdc_nyc tract fips are all present in geoid columns)
assert(no tract fips are missing from join)
assert(1:1 mapping between geoid and tract fips)

# %%
df_master.head()
# Out:
#          GEOID StateAbbr StateDesc CountyName  CountyFIPS     TractFIPS  \
# 0  36085024402        NY  New York   Richmond     36085.0  3.608502e+10
# 1  36085027705        NY  New York   Richmond     36085.0  3.608503e+10
# 2  36085012806        NY  New York   Richmond     36085.0  3.608501e+10
# 3  36047024400        NY  New York      Kings     36047.0  3.604702e+10
# 4  36047023000        NY  New York      Kings     36047.0  3.604702e+10
#
#    TotalPopulation TotalPop18plus  ACCESS2_CrudePrev ACCESS2_Crude95CI  ...  \
# 0           4381.0          3,520                4.8      ( 3.6,  6.2)  ...
# 1           5866.0          4,607                7.6      ( 6.1,  9.3)  ...
# 2           6659.0          5,274                8.6      ( 6.9, 10.4)  ...
# 3           3651.0          2,184               12.5      ( 9.9, 15.3)  ...
# 4           4442.0          2,512               16.0      (13.7, 18.4)  ...
#
#    FOODINSECU_Crude95CI HOUSINSECU_CrudePrev  HOUSINSECU_Crude95CI  \
# 0          ( 6.8, 11.8)                  9.0          ( 7.0, 11.1)
# 1          (13.2, 19.7)                 13.0          (10.8, 15.4)
# 2          (17.1, 23.9)                 16.0          (13.5, 18.5)
# 3          (25.1, 35.0)                 20.6          (17.3, 23.9)
# 4          (36.5, 44.9)                 27.6          (24.9, 30.9)
#
#   SHUTUTILITY_CrudePrev  SHUTUTILITY_Crude95CI LACKTRPT_CrudePrev  \
# 0                   4.9           ( 3.9,  6.0)                5.4
# 1                   6.9           ( 5.8,  8.1)                8.0
# 2                   9.4           ( 8.0, 10.9)               10.0
# 3                  12.1           (10.2, 14.1)               14.0
# 4                  18.4           (16.4, 20.7)               19.4
#
#    LACKTRPT_Crude95CI EMOTIONSPT_CrudePrev  EMOTIONSPT_Crude95CI  \
# 0        ( 4.4,  6.6)                 23.9          (20.1, 27.6)
# 1        ( 6.7,  9.4)                 29.2          (25.6, 33.1)
# 2        ( 8.5, 11.5)                 28.4          (24.8, 32.2)
# 3        (11.6, 16.3)                 31.2          (27.5, 34.9)
# 4        (17.3, 21.8)                 31.2          (28.2, 34.5)
#
#                       Geolocation
# 0  POINT (-74.2384712 40.4997874)
# 1   POINT (-74.156982 40.5882479)
# 2   POINT (-74.1076715 40.557671)
# 3  POINT (-73.9862364 40.6217475)
# 4   POINT (-73.9842809 40.637816)
#
# [5 rows x 89 columns]

# %%
# merge master with opportunity atlas

# %%
# merge master with acs data

# %% [markdown]
# ### 3. Save Data

# %%
# export processed tract data
df_master.to_parquet("data/processed/")
