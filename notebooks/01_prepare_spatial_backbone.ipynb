# %% [markdown]
# # 01 Prepare Spatial Backbone

# %% [markdown]
# **Project:** NORI
# **Author:** Yuseof J
# **Date:** 09/12/25
#
# ### **Purpose**
# Load the raw NY State tract shapefile, filter for NYC tracts, and set crs to Long Island/NYC.
#
# ### **Inputs**
# - `data/raw/tiger_tracts_ny/tl_2025_36_tract.shp`
#
# ### **Outputs**
# - `data/processed/nyc_tracts.gpkg`
#
# --------------------------------------------------------------------------

# %% [markdown]
# ### 0. Imports and Setup

# %%
# package imports
import os
import pandas as pd
import geopandas as gpd
from pathlib import Path

# specify filepaths
path_tracts_shapefile = 'data/raw/tiger_tracts_ny/tl_2025_36_tract.shp'
path_output_processed_geodata = 'data/processed/nyc_tracts.gpkg'
path_nyc_boroughs = 'data/raw/nyc_boroughs/nybbwi.shp'

# list of fips codes for nyc - used for filtering whole ny state dataset 
nyc_county_fips = ["005", "047", "061", "081", "085"]

# EPSG:2263 - this coordinate reference system is specifically used for high-accuracy mapping of nyc boroughs 
nyc_crs = 'EPSG:2263'

# ensure cwd is project root for file paths to function properly
project_root = Path(os.getcwd())            # get current directory
while not (project_root / "data").exists(): # keep moving up until in parent
    project_root = project_root.parent
os.chdir(project_root)                      # switch to parent directory

# %% [markdown]
# ### 1. Load Data

# %%
gdf_tracts = gpd.read_file(path_tracts_shapefile)
gdf_boroughs = gpd.read_file(path_nyc_boroughs)

# %% [markdown]
# ### 2. EDA

# %%
gdf_tracts.columns.tolist()
# Out:
# ['STATEFP',
#  'COUNTYFP',
#  'TRACTCE',
#  'GEOID',
#  'GEOIDFQ',
#  'NAME',
#  'NAMELSAD',
#  'MTFCC',
#  'FUNCSTAT',
#  'ALAND',
#  'AWATER',
#  'INTPTLAT',
#  'INTPTLON',
#  'geometry']

# %%
gdf_tracts.head()
# Out:
#   STATEFP COUNTYFP TRACTCE        GEOID               GEOIDFQ     NAME  \
# 0      36      029  008400  36029008400  1400000US36029008400       84
# 1      36      103  123600  36103123600  1400000US36103123600     1236
# 2      36      103  146001  36103146001  1400000US36103146001  1460.01
# 3      36      103  190402  36103190402  1400000US36103190402  1904.02
# 4      36      103  158709  36103158709  1400000US36103158709  1587.09
#
#                NAMELSAD  MTFCC FUNCSTAT     ALAND   AWATER     INTPTLAT  \
# 0       Census Tract 84  G5020        S  10966624  3505091  +42.9713848
# 1     Census Tract 1236  G5020        S   2302367  1082191  +40.6608399
# 2  Census Tract 1460.01  G5020        S   2225464        0  +40.7703277
# 3  Census Tract 1904.02  G5020        S  44073411    23956  +40.8468673
# 4  Census Tract 1587.09  G5020        S  13099359   110761  +40.8517499
#
#        INTPTLON                                           geometry
# 0  -078.9194986  POLYGON ((-78.94456 42.98506, -78.94216 42.992...
# 1  -073.4145754  POLYGON ((-73.42559 40.65629, -73.42529 40.656...
# 2  -073.2532537  POLYGON ((-73.26159 40.76307, -73.2615 40.7636...
# 3  -072.6336641  POLYGON ((-72.72668 40.8339, -72.72515 40.8387...
# 4  -072.9216255  POLYGON ((-72.94716 40.8556, -72.94649 40.8576...

# %%
gdf_boroughs.head()
# Out:
#    BoroCode       BoroName     Shape_Leng    Shape_Area  \
# 0         5  Staten Island  220557.476076  2.851518e+09
# 1         2          Bronx  188162.483488  1.598501e+09
# 2         4         Queens  459301.799089  4.962897e+09
# 3         1      Manhattan  203708.610992  9.443301e+08
# 4         3       Brooklyn  236476.766501  2.697661e+09
#
#                                             geometry
# 0  POLYGON ((968762.067 175987.749, 968654.251 17...
# 1  POLYGON ((1021632.336 267934.439, 1022108.577 ...
# 2  POLYGON ((1045438.075 235083.296, 1049675.845 ...
# 3  MULTIPOLYGON (((972081.788 190733.467, 972184....
# 4  POLYGON ((1004421.481 203543.225, 1004612.108 ...

# %% [markdown]
# ### 3. Data Processing and Filtering

# %%
# ensure county fips codes are properly formatted before filtering
gdf_tracts.COUNTYFP = gdf_tracts.COUNTYFP.apply(lambda x: str(x).zfill(3))

# filter for nyc boroughs
gdf_tracts_nyc = gdf_tracts[gdf_tracts.COUNTYFP.isin(nyc_county_fips)]

print("Total tracts: ", len(gdf_tracts_nyc))
# Out:
# Total tracts:  2327

# %%
# set coordinate reference system 
gdf_tracts_nyc = gdf_tracts_nyc.to_crs(nyc_crs)

# %% [markdown]
# Here we'll also add borough name. This will be useful for spatial CV in the ML pipeline. Tract centroid is used rather than tract boundaries to handle tracts that span borough boundaries.

# %%
# ensure same crs before sjoin
gdf_boroughs = gdf_boroughs.to_crs(nyc_crs)

# calculate tract centroids for point-in-polygon sjoin
gdf_tracts_nyc['centroid'] = gdf_tracts_nyc.geometry.centroid

# spatial join between tracts and broughs
gdf_tracts_nyc = gpd.sjoin(
    gdf_tracts_nyc.set_geometry('centroid'),
    gdf_boroughs[['BoroCode', 'BoroName', 'geometry']],
    how='left',
    predicate='within'
)

# drop unneeded columns
gdf_tracts_nyc.drop(columns=['index_right', 'centroid'], inplace=True)

# make sure all tracts have a borough
#assert(gdf_tracts_nyc.BoroName.isna().any() == False)

# %% [markdown]
# One tract did not join to a borough. Upon visual inspection in QGIS, this tract belongs to Manhattan. I'll set this manually.

# %%
# find unnasigned tract
# gdf_tracts_nyc[gdf_tracts_nyc.BoroName.isna()]

# set borough manually
gdf_tracts_nyc.loc[gdf_tracts_nyc.GEOID == '36061000100', ['BoroName', 'BoroCode']] = ['Manhattan', 1]

# %%
gdf_tracts_nyc[gdf_tracts_nyc.GEOID == '36061000100']
# Out:
#      STATEFP COUNTYFP TRACTCE        GEOID               GEOIDFQ NAME  \
# 1144      36      061  000100  36061000100  1400000US36061000100    1
#
#             NAMELSAD  MTFCC FUNCSTAT  ALAND  AWATER     INTPTLAT  \
# 1144  Census Tract 1  G5020        S  76389       0  +40.6899710
#
#           INTPTLON                                           geometry  \
# 1144  -074.0461025  MULTIPOLYGON (((972951.667 194368.81, 972956.3...
#
#       BoroCode   BoroName
# 1144       1.0  Manhattan

# %%
assert(gdf_tracts_nyc.BoroName.isna().any() == False)

# %%
gdf_tracts_nyc.head()
# Out:
#    STATEFP COUNTYFP TRACTCE        GEOID               GEOIDFQ    NAME  \
# 6       36      085  024402  36085024402  1400000US36085024402  244.02
# 7       36      085  027705  36085027705  1400000US36085027705  277.05
# 8       36      085  012806  36085012806  1400000US36085012806  128.06
# 48      36      047  024400  36047024400  1400000US36047024400     244
# 61      36      047  023000  36047023000  1400000US36047023000     230
#
#                NAMELSAD  MTFCC FUNCSTAT    ALAND   AWATER     INTPTLAT  \
# 6   Census Tract 244.02  G5020        S  1823028  2065530  +40.4997874
# 7   Census Tract 277.05  G5020        S   531529        0  +40.5882479
# 8   Census Tract 128.06  G5020        S  1319470   580167  +40.5576710
# 48     Census Tract 244  G5020        S   155278        0  +40.6217475
# 61     Census Tract 230  G5020        S   150941        0  +40.6378160
#
#         INTPTLON                                           geometry  BoroCode  \
# 6   -074.2384712  POLYGON ((912287.455 121583.989, 912302.099 12...       5.0
# 7   -074.1569820  POLYGON ((938978.947 152923.44, 939459.264 153...       5.0
# 8   -074.1076715  POLYGON ((950892.186 143465.985, 951155.755 14...       5.0
# 48  -073.9862364  POLYGON ((987168.126 166387.055, 987335.492 16...       3.0
# 61  -073.9842809  POLYGON ((987443.171 173158.468, 988054.351 17...       3.0
#
#          BoroName
# 6   Staten Island
# 7   Staten Island
# 8   Staten Island
# 48       Brooklyn
# 61       Brooklyn

# %% [markdown]
# ### 4. Save Data

# %%
# export processed tract data
gdf_tracts_nyc.to_file(path_output_processed_geodata, layer="tracts")
